# %% [markdown]
# ASSIGNMENT 1
# Basic Data Exploration and Cleaning Using Pandas
# Submitted By:
# Priyanshu Tiwari_ MMDU

# %% [markdown]
# Import Required Libraries

# %%
import pandas as pd

print("Pandas library imported successfully!")
# Out:
# Pandas library imported successfully!

# %% [markdown]
# Question 1: Load a CSV Dataset into a Pandas DataFrame

# %%
csv_1 = pd.read_csv("C:\\Users\\Priya\\OneDrive\\Documents\\My Docoument\\My Doc\\Celebal\\tshirts.csv")
csv_1
# Out:
#     product_id                      title  \
# 0     17352320                      ether
# 1     17403950             Mast & Harbour
# 2     17404018             Mast & Harbour
# 3     22143924                Urbano Plus
# 4     14619398                    ScoldMe
# 5      8901821               UNDER ARMOUR
# 6       919032                   Roadster
# 7     18817326             Tommy Hilfiger
# 8      8426447                      WROGN
# 9     20355284                   Roadster
# 10    18818696             Tommy Hilfiger
# 11     9213113                   Roadster
# 12    13511732                       Puma
# 13    13591994                      Camey
# 14    21439050                      Kappa
# 15    13615634            U.S. Polo Assn.
# 16    13620624                   Roadster
# 17    13502414                       Puma
# 18    13621134                   Roadster
# 19    17686030          Allen Solly Tribe
# 20    13616400             Arrow New York
# ...

# %% [markdown]
# Question 2: Explore Data (head/tail, shape, columns, data types)

# %%
csv_1.head()
# Out:
#    product_id           title  \
# 0    17352320           ether
# 1    17403950  Mast & Harbour
# 2    17404018  Mast & Harbour
# 3    22143924     Urbano Plus
# 4    14619398         ScoldMe
#
#                                  product_description  rating  ratings_count  \
# 0  Kora Collection Blue Sustainable Naturally Dye...     4.4             70
# 1          Men Mint Green Typography Printed T-shirt     4.2            200
# 2       Men Blue & White Striped Regular Fit T-shirt     3.9             72
# 3             Size Typography Printed Cotton T-shirt     3.2              6
# 4     Women Multicoloured Pack Of 2 Slim Fit T-shirt     0.0              0
#
#    initial_price  discount  final_price currency  \
# 0         1099.0      47.0  "₹1,099.00"      INR
# 1          899.0       NaN    "₹899.00"      INR
# 2          999.0       NaN    "₹999.00"      INR
# 3         1099.0      45.0  "₹1,099.00"      INR
# 4         1598.0      55.0    "₹719.00"      INR
#
# ...

# %%
csv_1.tail()
# Out:
#     product_id           title  \
# 34    22629260             max
# 35    19291812  Mad Over Print
# 36    19206288        FERANOID
# 37    19264534  Flying Machine
# 38    19264536  Flying Machine
#
#                                   product_description  rating  ratings_count  \
# 34          Striped Polo Collar Short Sleeves T-shirt     4.4              7
# 35             Women Black Love Wins Oversize T-shirt     4.8              5
# 36          Men Purple Henley Neck Bio Finish T-shirt     4.2             21
# 37  Men Black & White Printed Pure Cotton Slim Fit...     4.0            102
# 38  Men Rust Orange Melange Pure Cotton Slim Fit T...     3.8             60
#
#     initial_price  discount final_price currency  \
# 34          799.0      40.0   "₹479.00"      INR
# 35         1599.0      58.0   "₹671.00"      INR
# 36         1199.0      50.0   "₹599.00"      INR
# 37          999.0      61.0   "₹389.00"      INR
# 38         1299.0      61.0   "₹506.00"      INR
#
# ...

# %%
csv_1.shape
# Out:
# (39, 24)

# %%
csv_1.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
csv_1.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price             float64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %% [markdown]
# Question 3: Handle Missing Values (identify, fill/drop)

# %%
csv_1.isnull().sum()
# Out:
# product_id                 0
# title                      0
# product_description        0
# rating                     0
# ratings_count              0
# initial_price              0
# discount                   7
# final_price                0
# currency                   0
# images                     0
# delivery_options           0
# product_details            0
# breadcrumbs                0
# product_specifications     0
# amount_of_stars            0
# what_customers_said        9
# seller_name               21
# sizes                      0
# videos                    29
# seller_information        21
# variations                25
# best_offer                 0
# more_offers                0
# category                   0
# dtype: int64

# %%
csv_1.fillna("Not Available", inplace=True)

# %%
csv_1.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %% [markdown]
# Question 4: Perform Basic Operations (filter rows, select columns)

# %%
csv_1[csv_1['rating'] > 4]
# Out:
#     product_id                      title  \
# 0     17352320                      ether
# 1     17403950             Mast & Harbour
# 5      8901821               UNDER ARMOUR
# 7     18817326             Tommy Hilfiger
# 8      8426447                      WROGN
# 9     20355284                   Roadster
# 10    18818696             Tommy Hilfiger
# 11     9213113                   Roadster
# 12    13511732                       Puma
# 15    13615634            U.S. Polo Assn.
# 17    13502414                       Puma
# 18    13621134                   Roadster
# 19    17686030          Allen Solly Tribe
# 20    13616400             Arrow New York
# 21    13480864                Aeropostale
# 22    13622338                   Roadster
# 25    16277914                       Parx
# 26    16292318                   Bewakoof
# 27    19201678              Tokyo Talkies
# 28    16923916                Monte Carlo
# 30    20085320                    BULLMER
# ...

# %%
csv_1[['title', 'rating', 'initial_price']]
# Out:
#                         title  rating  initial_price
# 0                       ether     4.4         1099.0
# 1              Mast & Harbour     4.2          899.0
# 2              Mast & Harbour     3.9          999.0
# 3                 Urbano Plus     3.2         1099.0
# 4                     ScoldMe     0.0         1598.0
# 5                UNDER ARMOUR     4.3         1999.0
# 6                    Roadster     3.8          899.0
# 7              Tommy Hilfiger     4.4         2799.0
# 8                       WROGN     4.2         1599.0
# 9                    Roadster     4.2          999.0
# 10             Tommy Hilfiger     4.4         1999.0
# 11                   Roadster     4.1          799.0
# 12                       Puma     4.4         3999.0
# 13                      Camey     3.5          999.0
# 14                      Kappa     3.2          599.0
# 15            U.S. Polo Assn.     4.5         1699.0
# 16                   Roadster     4.0         1399.0
# ...

# %% [markdown]
# Question 5: Remove Duplicates

# %%
csv_1.drop_duplicates(inplace=True)

print("Duplicates removed successfully!")
# Out:
# Duplicates removed successfully!

# %% [markdown]
# Question 6: Create a Derived Column (total_amount = price * quantity)

# %%
# Converting discount column into numeric datatype
# Required for mathematical calculations

csv_1['discount'] = pd.to_numeric(csv_1['discount'], errors='coerce')

# %%
# Replacing missing discount values with 0
# Prevents calculation errors

csv_1['discount'] = csv_1['discount'].fillna(0)

# %%
# Creating price, quantity, and total_amount columns

csv_1['price'] = csv_1['initial_price'] - csv_1['discount']

csv_1['quantity'] = csv_1['ratings_count']

csv_1['total_amount'] = csv_1['price'] * csv_1['quantity']

# %%
 #Displaying derived columns

csv_1[['price','quantity','total_amount']].head()
# Out:
#     price  quantity  total_amount
# 0  1052.0        70       73640.0
# 1   899.0       200      179800.0
# 2   999.0        72       71928.0
# 3  1054.0         6        6324.0
# 4  1543.0         0           0.0

# %% [markdown]
# Question 7: Save the Cleaned Dataset as a New CSV File

# %%
csv_1.to_csv("cleaned_tshirts.csv", index=False)

# %%
cleaned_data = pd.read_csv("cleaned_tshirts.csv")

cleaned_data.head()
# Out:
#    product_id           title  \
# 0    17352320           ether
# 1    17403950  Mast & Harbour
# 2    17404018  Mast & Harbour
# 3    22143924     Urbano Plus
# 4    14619398         ScoldMe
#
#                                  product_description  rating  ratings_count  \
# 0  Kora Collection Blue Sustainable Naturally Dye...     4.4             70
# 1          Men Mint Green Typography Printed T-shirt     4.2            200
# 2       Men Blue & White Striped Regular Fit T-shirt     3.9             72
# 3             Size Typography Printed Cotton T-shirt     3.2              6
# 4     Women Multicoloured Pack Of 2 Slim Fit T-shirt     0.0              0
#
#    initial_price  discount  final_price currency  \
# 0         1099.0      47.0  "₹1,099.00"      INR
# 1          899.0       0.0    "₹899.00"      INR
# 2          999.0       0.0    "₹999.00"      INR
# 3         1099.0      45.0  "₹1,099.00"      INR
# 4         1598.0      55.0    "₹719.00"      INR
#
# ...
